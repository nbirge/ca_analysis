# %%
import sys
sys.path.insert(0,'/home/noah/Desktop/large_analysis/ca_analysis/')
from matplotlib.pyplot import*
import numpy as np
from scipy.constants import *
from matplotlib.colors import LogNorm
from scipy.constants import *
import fileread as fr
import predefined as pd

# %% [markdown]
# # Need to redo multi_0-window.npy (calibrated incorrectly)

# %%
path='/home/noah/Desktop/large_analysis/ca_analysis/cur_data/'
sim=np.load(path+'multi_0_window-100.npy')
real=np.load(path+'multi_0_window-100.npy')

# %%
data=fr.gen_output(path+'Run_120-all.dat')[0]
sim=fr.gen_output(path+'Run_0-all.dat')[0]
data=pd.precuts(data)
sim=pd.precuts(sim)


fs=35
fig,ax=subplots(figsize=(30,20))


ax.tick_params(labelsize=fs)
show()
